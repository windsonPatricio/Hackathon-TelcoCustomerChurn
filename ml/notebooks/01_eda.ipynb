# %% [markdown]
# # **Telco Churn - EDA**

# %% [markdown]
# **Descrição:** Notebook de Análise Exploratória (EDA) para o dataset *Telco Customer Churn*.
# **Objetivo:** inspecionar qualidade dos dados, gerar insights e preparar um dataset limpo para modelagem.

# %% [markdown]
# ## **Imports e configurações iniciais**

# %%
# Bibliotecas

from pathlib import Path
from math import ceil
from typing import Union, Callable, Optional

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
from scipy.stats.contingency import association
from scipy.stats import pointbiserialr
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.feature_selection import mutual_info_classif

# %% [markdown]
# ## **Definir caminhos (pathlib)**

# %%
# Considerando que este notebook está em ml/notebooks/
PROJECT_ROOT = Path.cwd().parents[1]

RAW_DATA_DIR = PROJECT_ROOT / "ml" / "data" / "raw"
PROCESSED_DATA_DIR = PROJECT_ROOT / "ml" / "data" / "processed"
DATA_PATH = RAW_DATA_DIR / "WA_Fn-UseC_-Telco-Customer-Churn.csv"

# %% [markdown]
# ## **Carregar dados**

# %%
# Carrega o dataset
telecom_raw_df = pd.read_csv(DATA_PATH, low_memory=False)

# %% [markdown]
# ## **Visão geral do dataset**

# %%
# Visualiza uma amostra dos dados
telecom_raw_df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 934   4198-VFOEA  Female              0      No         No      12
# 4202  3146-JTQHR    Male              0     Yes         No      10
# 6312  7055-VKGDA    Male              0      No         No      54
# 740   4381-MHQDC  Female              0      No         No      47
# 1728  8345-MVDYC  Female              0      No         No      45
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 934            No  No phone service             DSL                  Yes  ...
# 4202          Yes                No              No  No internet service  ...
# 6312          Yes                No     Fiber optic                  Yes  ...
# 740           Yes               Yes             DSL                  Yes  ...
# 1728          Yes                No             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# ### **Shape e tipos**

# %%
# Dimensão do dataset
telecom_raw_df.shape
# Out:
# (7043, 21)

# %%
# Tipo de dados das colunas
telecom_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### **Valores nulos e duplicados**

# %%
# Valores nulos por coluna
telecom_raw_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Aparente não há valores nulos ou duplicados no dataset. Mas é importante investigar mais a fundo. Será que há valores vazios representados como strings?

# %%
# Verifica a existência de valores vazios representados como strings
telecom_raw_df.select_dtypes(include=['object']).apply(lambda x: x.str.strip() == '').sum()
# Out:
# customerID           0
# gender               0
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Olha os valores únicos da coluna 'TotalCharges'
telecom_raw_df['TotalCharges'].value_counts().reset_index().head(5)
# Out:
#   TotalCharges  count
# 0                  11
# 1         20.2     11
# 2        19.75      9
# 3        20.05      8
# 4         19.9      8

# %% [markdown]
# Na coluna `TotalCharges`, por exemplo, há valores vazios representados como strings.

# %%
# Valores duplicados
telecom_raw_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Valores únicos por coluna**

# %%
# Valores unicos para as colunas do tipo object
telecom_raw_df.select_dtypes(include=['object']).nunique()
# Out:
# customerID          7043
# gender                 2
# Partner                2
# Dependents             2
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %% [markdown]
# ## **Limpeza inicial / normalização de strings**

# %%
# Cria uma cópia do dataset para evitar modificar o original
telecom_df = telecom_raw_df.copy()

# %%
# limpeza preliminar (strip strings)
for c in telecom_df.select_dtypes(include="object").columns:
    telecom_df[c] = telecom_df[c].astype(str).str.strip()

# %% [markdown]
# ## **Substituir strings vazias por NaN**

# %%
# Substitui valores em branco por np.nan
telecom_df['TotalCharges'] = telecom_df['TotalCharges'].replace('', np.nan)

# Verifica se a substituição foi feita corretamente
telecom_df['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %% [markdown]
# ## **Renomear colunas**

# %%
# Mapping dos nomes das colunas (original -> português)

mapping = {
    "customerID": "id_cliente",
    "gender": "genero",
    "SeniorCitizen": "idoso",
    "Partner": "parceiro",
    "Dependents": "dependentes",
    "tenure": "tempo_contrato_meses",
    "PhoneService": "servico_telefone",
    "MultipleLines": "linhas_multiplas",
    "InternetService": "tipo_internet",
    "OnlineSecurity": "seguranca_online",
    "OnlineBackup": "backup_online",
    "DeviceProtection": "protecao_dispositivo",
    "TechSupport": "suporte_tecnico",
    "StreamingTV": "streaming_tv",
    "StreamingMovies": "streaming_filmes",
    "Contract": "tipo_contrato",
    "PaperlessBilling": "cobranca_digital",
    "PaymentMethod": "metodo_pagamento",
    "MonthlyCharges": "cobranca_mensal",
    "TotalCharges": "cobranca_total",
    "Churn": "churn"
}

# %%
# Aplicar rename e salvar mapping
telecom_df.rename(columns=mapping, inplace=True)

# %%
# Verifica a mudança de nomes
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_cliente            7043 non-null   object
#  1   genero                7043 non-null   object
#  2   idoso                 7043 non-null   int64
#  3   parceiro              7043 non-null   object
#  4   dependentes           7043 non-null   object
#  5   tempo_contrato_meses  7043 non-null   int64
#  6   servico_telefone      7043 non-null   object
#  7   linhas_multiplas      7043 non-null   object
#  8   tipo_internet         7043 non-null   object
#  9   seguranca_online      7043 non-null   object
#  10  backup_online         7043 non-null   object
#  11  protecao_dispositivo  7043 non-null   object
#  12  suporte_tecnico       7043 non-null   object
#  13  streaming_tv          7043 non-null   object
#  14  streaming_filmes      7043 non-null   object
# ...

# %% [markdown]
# ## **Padronização dos valores das variáveis**

# %%
def apply_maps(df: pd.DataFrame, maps: dict) -> pd.DataFrame:
    for col, mp in maps.items():
        if col in df.columns:
            df[col] = df[col].replace(mp)
    return df

# %% [markdown]
# **Mapeamentos das variáveis categóricas**

# %%
category_value_maps = {
    "genero": {
        "Male": "homem",
        "Female": "mulher"
    },
    "linhas_multiplas": {
        "No phone service": "sem_telefone",
        "No": "nao",
        "Yes": "sim"
    },
    "tipo_internet": {
        "DSL": "dsl",
        "Fiber optic": "fibra",
        "No": "sem_internet"
    },
    "seguranca_online": {
        "No internet service": "sem_internet",
        "No": "nao",
        "Yes": "sim"
    },
    "backup_online": {
        "No internet service": "sem_internet",
        "No": "nao",
        "Yes": "sim"
    },
    "protecao_dispositivo": {
        "No internet service": "sem_internet",
        "No": "nao",
        "Yes": "sim"
    },
    "suporte_tecnico": {
        "No internet service": "sem_internet",
        "No": "nao",
        "Yes": "sim"
    },
    "streaming_tv": {
        "No internet service": "sem_internet",
        "No": "nao",
        "Yes": "sim"
    },
    "streaming_filmes": {
        "No internet service": "sem_internet",
        "No": "nao",
        "Yes": "sim"
    },
    "tipo_contrato": {
        "Month-to-month": "mensal",
        "One year": "um_ano",
        "Two year": "dois_anos"
    },
    "metodo_pagamento": {
        "Electronic check": "cheque_eletronico",
        "Mailed check": "cheque_enviado",
        "Bank transfer (automatic)": "transferencia_bancaria_automatica",
        "Credit card (automatic)": "cartao_credito_automatica"
    }
} 

# Aplica os mapeamentos de valores
telecom_df = apply_maps(telecom_df, category_value_maps)

# %% [markdown]
# #### **Mapeamentos das variáveis binárias**

# %%
binary_value_maps = {
    "idoso": {0: 0, 1: 1},  # opcional, só pra documentar
    "parceiro": {"Yes": 1, "No": 0},
    "dependentes": {"Yes": 1, "No": 0},
    "servico_telefone": {"Yes": 1, "No": 0},
    "cobranca_digital": {"Yes": 1, "No": 0}
}

# Aplica os mapeamentos de valores
telecom_df = apply_maps(telecom_df, binary_value_maps)
# Out:
# /tmp/ipykernel_300958/832868481.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace(mp)

# %% [markdown]
# ### **Codificação do target `churn`**

# %%
# Codificação do target `churn`
telecom_df["churn"] = telecom_df["churn"].map({"Yes": 1, "No": 0})

# %%
# Verifica a tradução
telecom_df.sample(5)
# Out:
#       id_cliente  genero  idoso  parceiro  dependentes  tempo_contrato_meses  \
# 5926  1356-MKYSK   homem      0         0            0                     6
# 4663  0722-TROQR  mulher      1         0            0                     4
# 104   3192-NQECA   homem      0         1            0                    68
# 3146  4236-XPXAV  mulher      0         1            1                     5
# 652   5845-BZZIB   homem      0         1            1                    35
#
#       servico_telefone linhas_multiplas tipo_internet seguranca_online  ...  \
# 5926                 1              nao           dsl              sim  ...
# 4663                 1              sim         fibra              nao  ...
# 104                  1              sim         fibra              nao  ...
# 3146                 1              nao         fibra              nao  ...
# 652                  1              nao  sem_internet     sem_internet  ...
#
# ...

# %% [markdown]
# ## **Conversão de tipos**

# %% [markdown]
# ### **Colunas string → `str`**

# %%
str_cols = [
    "id_cliente"
]

telecom_df[str_cols] = telecom_df[str_cols].astype("string")

# %% [markdown]
# ### **Colunas categóricas → `pd.Categorical`**

# %%
categorical_cols = [
    "genero",
    "linhas_multiplas",
    "tipo_internet",
    "seguranca_online",
    "backup_online",
    "protecao_dispositivo",
    "suporte_tecnico",
    "streaming_tv",
    "streaming_filmes",
    "tipo_contrato",
    "metodo_pagamento"
]

telecom_df[categorical_cols] = telecom_df[categorical_cols].astype("category")

# %% [markdown]
# ### **Colunas numéricas → `float` / `int`**

# %%
float_cols = [
    "cobranca_mensal",
    "cobranca_total"
]

telecom_df[float_cols] = telecom_df[float_cols].astype("float32")

# %%
integer_cols = [
    "tempo_contrato_meses"
]

telecom_df[integer_cols] = telecom_df[integer_cols].astype("int16")

# %%
binary_cols = [
    "idoso",
    "parceiro",
    "dependentes",
    "servico_telefone",
    "cobranca_digital"
]

telecom_df[binary_cols] = telecom_df[binary_cols].astype("int8")

# %% [markdown]
# ### **Target `churn` → `int`**

# %%
telecom_df["churn"] = telecom_df["churn"].astype("int8")

# %%
# Verifica o resultado final
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_cliente            7043 non-null   string
#  1   genero                7043 non-null   category
#  2   idoso                 7043 non-null   int8
#  3   parceiro              7043 non-null   int8
#  4   dependentes           7043 non-null   int8
#  5   tempo_contrato_meses  7043 non-null   int16
#  6   servico_telefone      7043 non-null   int8
#  7   linhas_multiplas      7043 non-null   category
#  8   tipo_internet         7043 non-null   category
#  9   seguranca_online      7043 non-null   category
#  10  backup_online         7043 non-null   category
#  11  protecao_dispositivo  7043 non-null   category
#  12  suporte_tecnico       7043 non-null   category
#  13  streaming_tv          7043 non-null   category
# ...

# %%
# Verifica uma amostra dos dados
telecom_df.sample(5)
# Out:
#       id_cliente  genero  idoso  parceiro  dependentes  tempo_contrato_meses  \
# 3729  3635-QQRQD   homem      0         0            0                    62
# 6298  7356-IWLFW   homem      0         1            1                    46
# 6123  0623-EJQEG   homem      0         0            0                    65
# 4568  3709-OIJEA   homem      0         0            0                    26
# 2474  5630-IXDXV  mulher      0         0            0                    47
#
#       servico_telefone linhas_multiplas tipo_internet seguranca_online  ...  \
# 3729                 1              nao  sem_internet     sem_internet  ...
# 6298                 1              sim         fibra              nao  ...
# 6123                 1              sim         fibra              sim  ...
# 4568                 1              nao         fibra              nao  ...
# 2474                 1              sim         fibra              nao  ...
#
# ...

# %% [markdown]
# ## **Excluir a coluna `id_cliente`**

# %%
# Exclui a coluna id_cliente
telecom_df.drop(columns=["id_cliente"], inplace=True)

# %% [markdown]
# ## **Schema final dos dados**

# %% [markdown]
# | Campo                  | Descrição                               | Tipo (Pandas)        | Tipo (API / Java)  |
# | ---------------------- | --------------------------------------- | -------------------- | ------------------ |
# | `genero`               | Gênero do cliente                       | `category`           | `String` / `Enum`  |
# | `idoso`                | Cliente é idoso (1 = sim, 0 = não)      | `int8`               | `Integer` (0/1)    |
# | `parceiro`             | Possui parceiro(a)                      | `int8`               | `Integer` (0/1)    |
# | `dependentes`          | Possui dependentes                      | `int8`               | `Integer` (0/1)    |
# | `tempo_contrato_meses` | Tempo de contrato em meses              | `int16`              | `Integer`          |
# | `servico_telefone`     | Possui serviço de telefone              | `int8`               | `Integer` (0/1)    |
# | `linhas_multiplas`     | Possui múltiplas linhas                 | `category`           | `String` / `Enum`  |
# | `tipo_internet`        | Tipo de internet contratada             | `category`           | `String` / `Enum`  |
# | `seguranca_online`     | Serviço de segurança online             | `category`           | `String` / `Enum`  |
# | `backup_online`        | Serviço de backup online                | `category`           | `String` / `Enum`  |
# | `protecao_dispositivo` | Proteção de dispositivo                 | `category`           | `String` / `Enum`  |
# | `suporte_tecnico`      | Suporte técnico                         | `category`           | `String` / `Enum`  |
# | `streaming_tv`         | Serviço de streaming de TV              | `category`           | `String` / `Enum`  |
# | `streaming_filmes`     | Serviço de streaming de filmes          | `category`           | `String` / `Enum`  |
# | `tipo_contrato`        | Tipo de contrato                        | `category`           | `String` / `Enum`  |
# | `cobranca_digital`     | Fatura digital ativa (1 = sim, 0 = não) | `int8`               | `Integer` (0/1)    |
# | `metodo_pagamento`     | Método de pagamento                     | `category`           | `String` / `Enum`  |
# | `cobranca_mensal`      | Valor mensal cobrado (ex.: 79.85)       | `float32`            | `Float` / `Double` |
# | `cobranca_total`       | Valor total cobrado (pode ser `null`)   | `float32` (nullable) | `Float` / `Double` |

# %% [markdown]
# ## **Estatísticas descritivas**

# %% [markdown]
# ### **Categóricas (summary)**

# %%
# Estatísticas descritivas do DataFrame para os dados categóricos
telecom_df.describe(include='category')
# Out:
#        genero linhas_multiplas tipo_internet seguranca_online backup_online  \
# count    7043             7043          7043             7043          7043
# unique      2                3             3                3             3
# top     homem              nao         fibra              nao           nao
# freq     3555             3390          3096             3498          3088
#
#        protecao_dispositivo suporte_tecnico streaming_tv streaming_filmes  \
# count                  7043            7043         7043             7043
# unique                    3               3            3                3
# top                     nao             nao          nao              nao
# freq                   3095            3473         2810             2785
#
#        tipo_contrato   metodo_pagamento
# count           7043               7043
# unique             3                  4
# top           mensal  cheque_eletronico
# freq            3875               2365

# %% [markdown]
# Analisando o resumo das variáveis categóricas apresentadas, observa-se que o conjunto de dados é composto por **7 043 clientes** em todas as variáveis, sem registros ausentes. A variável **gênero** apresenta apenas duas categorias, com leve predominância de **homens** (3 555), indicando uma distribuição relativamente equilibrada entre os sexos.
#
# No que se refere aos serviços telefônicos, a maioria dos clientes **não possui linhas múltiplas** (`linhas_multiplas = nao`, 3 390), sugerindo que grande parte utiliza apenas uma linha telefônica. Em relação ao **tipo de internet**, a opção **fibra** é a mais frequente (3 096), o que indica preferência por conexões de maior velocidade.
#
# Observando os serviços adicionais de internet - **segurança online**, **backup online**, **proteção de dispositivo** e **suporte técnico** - nota-se que, em todos os casos, a categoria **“não”** é predominante. Isso sugere que a maioria dos clientes opta apenas pelo serviço básico de internet, sem contratar pacotes adicionais de proteção ou suporte.
#
# O mesmo padrão é observado para os serviços de entretenimento: tanto **streaming de TV** quanto **streaming de filmes** são majoritariamente **não contratados**, reforçando a ideia de um perfil de consumo mais conservador em relação a serviços extras.
#
# Por fim, no aspecto contratual e financeiro, o **tipo de contrato mensal** (`mensal`) é claramente dominante (3 875), evidenciando a preferência dos clientes por maior flexibilidade e menor compromisso de longo prazo. Quanto ao **método de pagamento**, o mais utilizado é o **cheque eletrônico** (2 365), indicando uma forte adesão a meios de pagamento digitais.

# %% [markdown]
# ### **Numéricas (summary)**

# %%
# Estatísticas descritivas do DataFrame para os dados numéricos
telecom_df.describe(include='number')
# Out:
#              idoso     parceiro  dependentes  tempo_contrato_meses  \
# count  7043.000000  7043.000000  7043.000000           7043.000000
# mean      0.162147     0.483033     0.299588             32.371149
# std       0.368612     0.499748     0.458110             24.559481
# min       0.000000     0.000000     0.000000              0.000000
# 25%       0.000000     0.000000     0.000000              9.000000
# 50%       0.000000     0.000000     0.000000             29.000000
# 75%       0.000000     1.000000     1.000000             55.000000
# max       1.000000     1.000000     1.000000             72.000000
#
#        servico_telefone  cobranca_digital  cobranca_mensal  cobranca_total  \
# count       7043.000000       7043.000000      7043.000000     7032.000000
# mean           0.903166          0.592219        64.761696     2283.300537
# std            0.295752          0.491457        30.090048     2266.771484
# ...

# %% [markdown]
# A análise descritiva das variáveis numéricas e binárias mostra que o conjunto de dados possui **7 043 clientes**, com exceção da variável **cobrança total** (`cobranca_total`), que apresenta **11 valores ausentes**, o que deve ser tratado antes de análises mais aprofundadas ou da modelagem.
#
# Em termos de perfil demográfico, apenas **16,2 %** dos clientes são **idosos** (`idoso = 1`), indicando que a base é composta majoritariamente por clientes não idosos. A presença de **parceiro** é relativamente equilibrada (média de 0,48), enquanto apenas cerca de **30 %** possuem **dependentes**, reforçando um perfil com menor responsabilidade familiar.
#
# O **tempo de contrato** apresenta média de aproximadamente **32 meses**, mas com alta variabilidade (desvio-padrão de 24,6 meses). A mediana de **29 meses** e o intervalo de 0 a 72 meses indicam uma base heterogênea, composta tanto por clientes recentes quanto por clientes de longa permanência.
#
# Quanto aos serviços, a grande maioria dos clientes possui **serviço de telefone** (`servico_telefone = 1`, cerca de 90 %), e mais da metade utiliza **cobrança digital** (`cobranca_digital = 1`, ~59 %), evidenciando uma adoção relevante de canais digitais de faturamento.
#
# No aspecto financeiro, a **cobrança mensal** média é de aproximadamente **R$ 64,76**, com valores variando de **R$ 18,25** a **R$ 118,75**, o que indica diversidade nos planos contratados. Já a **cobrança total** apresenta média de **R$ 2.283,30**, fortemente influenciada pelo tempo de contrato, como sugerem os quartis e o elevado desvio-padrão.
#
# Por fim, a variável **churn** apresenta média de **0,265**, indicando que cerca de **26,5 %** dos clientes cancelaram o serviço. Esse valor confirma um **desbalanceamento moderado** entre as classes, que deve ser considerado em análises preditivas e no treinamento de modelos de machine learning.

# %% [markdown]
# ## **Distribuição da variável alvo (Churn)**

# %%
# Cria a figura e o eixo
fig, ax = plt.subplots(figsize=(6, 5))

# Ajusta espaço superior para o suptitle
fig.subplots_adjust(top=0.90)

# Título geral da figura
fig.suptitle('Distribuição de Clientes por Status de Churn',
             fontsize=18, fontweight='bold')

# Plota o countplot
sns.countplot(
    data=telecom_df,
    x='churn',
    order=[0, 1],
    ax=ax
)

# Rótulos dos eixos
ax.set_xlabel('Churn', fontsize=14)
ax.set_ylabel('Número de Clientes', fontsize=14)
ax.set_xticks([0, 1])
ax.set_xticklabels(['Não cancelou', 'Cancelou'])

# Remove spine superior e direita, e y-ticks
sns.despine()
ax.tick_params(axis='y', left=False, labelleft=False)
# ax.grid(axis='y', color='lightgray', linestyle='--', linewidth=0.5)

# Garantir folga no topo para as anotações
max_height = max(p.get_height() for p in ax.patches)
ax.set_ylim(0, max_height * 1.15)

# Anotações com contagem e porcentagem
total = len(telecom_df)
for p in ax.patches:
    count = int(p.get_height())
    pct = count / total * 100
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    offset = max_height * 0.02  # 2% do valor máximo
    ax.annotate(f'{count}\n({pct:.1f}%)',
                (x, y + offset),
                ha='center',
                va='bottom',
                fontsize=12,
                fontweight='semibold')

# Salva o gráfico
#fig.savefig(plots_dir / 'churn_distribution.png', bbox_inches='tight', dpi=300)

# Exibe o gráfico
plt.show()

# %% [markdown]
# Como podemos observar, se trata de um problema de classificação desbalanceada, onde a maioria dos clientes não cancelou o serviço. Isso é comum em problemas de churn, importante ter isso em mente ao desenvolver modelos preditivos, dado que isso produz grandes impactos na performance dos modelos.

# %% [markdown]
# ## **Análise univariada - variáveis categóricas**

# %%
# Lista de colunas categóricas, desonsiderando 'Churn' e costumerID
categorical_columns = (
    telecom_df
    .select_dtypes(include=['object', 'category'])
    .columns
    .difference(['Churn', 'customerID'])
    .tolist()
)

# %%
# Outro método para obter colunas categóricas
categorical_columns = [
    col for col in telecom_df.select_dtypes(include=['object', 'category'])
    if col not in ('Churn', 'customerID')
]

# %%
# Define a figura com base no número de colunas categóricas
n = len(categorical_columns)
ncols = 2
nrows = ceil(n / ncols)

fig, axes = plt.subplots(nrows, ncols, figsize=(12, nrows * 4),
                         sharey=True)

# Achata os eixos para facilitar o loop
axes = axes.flatten()

# Loop para plotar cada coluna categórica
for ax, var in zip(axes, categorical_columns):
    sns.countplot(
        data=telecom_df,
        x=var,
        order=telecom_df[var].value_counts().index,
        ax=ax
    )
    
    # Título e rótulos dos eixos
    ax.set_title(f'{var}', fontsize=12, fontweight='bold')
    ax.set_xlabel('') # Sem rótulo no eixo x
    ax.set_ylabel('Número de Clientes', fontsize=12)
    # Rotaciona os labels para evitar sobreposição
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_ha('right')
            

    # Despine
    sns.despine(ax=ax)

# Título geral e ajuste do layout
fig.suptitle('Churn vs. Variáveis Categóricas', 
             fontsize=18, fontweight='bold', ha='center')
fig.subplots_adjust(hspace=0.5, wspace=0.3, top=0.92)


# Ajusta o layout para evitar sobreposição
plt.tight_layout(rect=[0, 0, 1, 0.98])

# Deleta o eixos extras, se houver
for i in range(len(categorical_columns), len(axes)):
    fig.delaxes(axes[i])

# Salva o gráfico
#fig.savefig(plots_dir / 'churn_vs_categorical_variables.png', bbox_inches='tight', dpi=300)

# Exibe o gráfico
plt.show()

# %% [markdown]
# ## **Análise univariada - variáveis numéricas**

# %%
# Lista de variáveis numéricas
numeric_columns = telecom_df.select_dtypes(include=['number']).columns.tolist()

# %%
# Define o número de colunas e linhas para os subplots
n = len(numeric_columns)
ncols = 2
nrows = ceil(n / ncols)

# Cria a figura
fig, axes = plt.subplots(nrows, ncols, figsize=(12, nrows * 4), sharey=False)

# Achata os eixos para facilitar o loop
axes = axes.flatten()

# Plota o histograma
for ax, var in zip(axes, numeric_columns):
    sns.histplot(
        data=telecom_df,
        x=var,
        kde=True,
        stat='count',
        multiple='dodge',
        common_norm=False,
        ax=ax
    )
    
    # Título e rótulos dos eixos
    ax.set_title(f'{var}', fontsize=12, fontweight='bold')
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Número de Clientes', fontsize=12)
    
    # Despine
    sns.despine(ax=ax)
    
# Título geral da figura
fig.suptitle('Distribuição de Variáveis Numéricas por Status de Churn', 
             fontsize=18, fontweight='bold', ha='center')

# Ajustes de layout e espaçamento
fig.subplots_adjust(hspace=0.4, wspace=0.3, top=0.92)

# Gira as labels do eixo x
for ax in axes:
    ax.tick_params(axis='x', labelrotation=45)
    ax.grid(axis='y', linestyle='--', linewidth=0.5, color='lightgray')

# Remove eixos não utilizados (caso número de variáveis seja ímpar)
for i in range(n, len(axes)):
    fig.delaxes(axes[i])

# Ajusta o layout para evitar sobreposição
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Salva o gráfico
#fig.savefig(plots_dir / 'churn_vs_numeric_variables.png', bbox_inches='tight', dpi=300)

# Exibe o gráfico
plt.show()

# %% [markdown]
# ## **Análise bivariada - categóricas vs Churn**

# %%
# Define a figura com base no número de colunas categóricas
n = len(categorical_columns)
ncols = 2
nrows = ceil(n / ncols)

fig, axes = plt.subplots(nrows, ncols, figsize=(12, nrows * 4),
                         sharey=True)

# Achata os eixos para facilitar o loop
axes = axes.flatten()

# Loop para plotar cada coluna categórica
for ax, var in zip(axes, categorical_columns):
    sns.countplot(
        data=telecom_df,
        x=var,
        hue='churn',
        order=telecom_df[var].value_counts().index,
        ax=ax
    )
    
    # Título e rótulos dos eixos
    ax.set_title(f'{var}', fontsize=12, fontweight='bold')
    ax.set_xlabel('') # Sem rótulo no eixo x
    ax.set_ylabel('Número de Clientes', fontsize=12)
    # Rotaciona os labels para evitar sobreposição
    for label in ax.get_xticklabels():
        label.set_rotation(45)
        label.set_ha('right')
            

    # Despine
    sns.despine(ax=ax)

# Título geral e ajuste do layout
fig.suptitle('Churn vs. Variáveis Categóricas', 
             fontsize=18, fontweight='bold', ha='center')
fig.subplots_adjust(hspace=0.5, wspace=0.3, top=0.92)


# Ajusta o layout para evitar sobreposição
plt.tight_layout(rect=[0, 0, 1, 0.98])

# Deleta o eixos extras, se houver
for i in range(len(categorical_columns), len(axes)):
    fig.delaxes(axes[i])

# Salva o gráfico
#fig.savefig(plots_dir / 'churn_vs_categorical_variables.png', bbox_inches='tight', dpi=300)

# Exibe o gráfico
plt.show()

# %% [markdown]
# ### **Testes estatísticos para categóricas**

# %% [markdown]
# #### **Teste de Qui-quadrado**

# %% [markdown]
# **Entendendo o Teste de Qui-Quadrado**
#
# O valor de $\chi^2$ vem do **teste de independência do Qui-quadrado de Pearson**. No contexto de Churn, ele busca responder:
# > *"A diferença entre quem cancelou e quem ficou é aleatória, ou existe um padrão real?"*
#
# A estatística é calculada por:
#
# $$
# \chi^2 = \sum_{i=1}^{r} \sum_{j=1}^{k} \frac{(O_{ij} - E_{ij})^2}{E_{ij}}
# $$
#
# **1. Intuição (O "Porquê")**
# Imagine um mundo onde **nenhuma variável importa**. Nesse mundo, se 20% dos clientes cancelam no geral, esperamos que 20% dos Homens cancelem e 20% das Mulheres cancelem.
# - **Valor Esperado ($E_{ij}$):** É o que deveria acontecer nesse mundo "perfeito" e sem padrões.
# - **Valor Observado ($O_{ij}$):** É a realidade nua e crua (o que está nos dados).
#
# Se a Realidade ($O$) for muito diferente da Expectativa ($E$), significa que **algo está acontecendo**. A variável tem influência!
#
# **2. A Matemática (O "Como")**
# A fórmula funciona como uma balança de discrepâncias. Vamos quebrar os termos:
#
# 1.  **A Diferença $(O_{ij} - E_{ij})$:**
#     Calculamos a distância entre a realidade e a expectativa. Se for zero, tudo ocorreu exatamente como o esperado (sem associação).
#
# 2.  **O Quadrado $(...)^2$:**
#     Elevamos ao quadrado para eliminar sinais negativos. Não importa se o desvio foi para cima ou para baixo, queremos medir a **magnitude** do erro. Além disso, o quadrado penaliza grandes desvios mais severamente.
#
# 3.  **A Divisão por $E_{ij}$ (Normalização):**
#     Esta é a parte genial. Um erro de 5 pessoas é grave se esperávamos apenas 10 (erro de 50%), mas irrelevante se esperávamos 10.000 (erro de 0,05%). Dividir pelo esperado coloca o erro em perspectiva relativa.
#
# 4.  **O Somatório $\sum$:**
#     Somamos essas "notas de discrepância" de todas as células da tabela.
#     - **$\chi^2$ Alto:** Muita discrepância $\rightarrow$ Forte indício de associação (A variável impacta o Churn).
#     - **$\chi^2$ Baixo (próximo de 0):** Realidade igual à Expectativa $\rightarrow$ Independência (A variável não serve para nada).
#
# **3. Como calcular o Esperado ($E_{ij}$):**
# Para cada célula, o valor teórico é calculado cruzando os totais da linha e da coluna:
#
# $$
# E_{ij} = \frac{(\text{Total da Linha } i) \times (\text{Total da Coluna } j)}{\text{Total Geral da Amostra}}
# $$

# %%
# Loop para calcular o teste de Qui-quadrado para cada coluna categórica
for col in categorical_columns:
    ct = pd.crosstab(telecom_df[col], telecom_df['churn'])
    chi2, p, dof, _ = chi2_contingency(ct)
    print(f"{col}: chi2 = {chi2:.2f}, p = {p:.4f}")
# Out:
# genero: chi2 = 0.48, p = 0.4866
# linhas_multiplas: chi2 = 11.33, p = 0.0035
# tipo_internet: chi2 = 732.31, p = 0.0000
# seguranca_online: chi2 = 850.00, p = 0.0000
# backup_online: chi2 = 601.81, p = 0.0000
# protecao_dispositivo: chi2 = 558.42, p = 0.0000
# suporte_tecnico: chi2 = 828.20, p = 0.0000
# streaming_tv: chi2 = 374.20, p = 0.0000
# streaming_filmes: chi2 = 375.66, p = 0.0000
# tipo_contrato: chi2 = 1184.60, p = 0.0000
# metodo_pagamento: chi2 = 648.14, p = 0.0000

# %% [markdown]
# Ao examinar os resultados do teste de Qui-quadrado, observamos uma forte polarização nas variáveis: enquanto características demográficas básicas parecem irrelevantes, os atributos relacionados ao contrato e aos serviços de suporte técnico mostram-se determinantes para o churn.
#
# As variáveis com maior poder de discriminação são aquelas ligadas à fidelidade e estrutura da conta. O destaque absoluto é **tipo_contrato** ($\chi^2 = 1184.60, p = 0.0000$), que apresenta o maior valor estatístico de todo o dataset, seguido por **metodo_pagamento** ($\chi^2 = 648.14, p = 0.0000$). Isso sugere fortemente que a forma como o cliente está vinculado financeiramente à empresa é o maior indicador de risco de cancelamento.
#
# Além disso, nota-se que serviços de valor agregado funcionam como fortes retentores. Variáveis como **seguranca_online** ($\chi^2 = 850.00$), **suporte_tecnico** ($\chi^2 = 828.20$) e **backup_online** ($\chi^2 = 601.81$) possuem associações extremamente altas. Curiosamente, serviços de entretenimento como **streaming_tv** e **streaming_filmes** ($\chi^2 \approx 375$) também são significativos, mas têm praticamente metade da força de associação dos serviços de segurança e suporte.
#
# Em contrapartida, a variável **genero** ($\chi^2 = 0.48, p = 0.4866$) não apresenta significância estatística ($p > 0.05$), **devendo ser avalida com outras análises para avaliar a necessidade de sua presença**. Vale uma observação sobre **linhas_multiplas**: embora seja estatisticamente significativa ($p = 0.0035$), seu valor de qui-quadrado ($\chi^2 = 11.33$) é drasticamente inferior às demais, indicando que ter múltiplas linhas tem um impacto marginal na decisão de saída comparado a outros fatores.

# %% [markdown]
# #### **V de Cramér: Medindo a Força da Associação**

# %% [markdown]
# Enquanto o teste de Qui-quadrado, que vimos acima, nos responde **se** existe uma associação estatisticamente significativa (através do p-valor), ele falha em nos dizer **o quão forte** é essa relação. Um valor de $\chi^2$ alto pode ser apenas fruto de uma amostra muito grande, e não necessariamente de uma correlação forte.
#
# Para resolver isso e podermos comparar variáveis entre si, utilizamos o **V de Cramér**.
#
# Esta métrica normaliza o resultado do Qui-quadrado para uma escala padronizada entre **0 e 1**, removendo o viés do tamanho da amostra e da quantidade de categorias.
#
# **Interpretação da Escala:**
# - **0.0:** Variáveis estatisticamente independentes (nenhuma associação).
# - **1.0:** Associação perfeita (saber o valor de uma variável permite prever a outra com certeza).
#
# **A Fórmula:**
#
# $$
# V = \sqrt{\frac{\chi^2}{n \cdot \min(k-1, r-1)}}
# $$
#
# **Onde:**
# - $\chi^2$: É a estatística calculada no teste de Qui-quadrado.
# - $n$: Número total de observações (linhas) do dataset.
# - $\min(k-1, r-1)$: É o fator de correção para a dimensão da tabela (o menor valor entre o número de colunas menos 1 e linhas menos 1).
#
# **Aplicação no Churn:**
# Essa medida é essencial para nossa EDA, pois nos permite criar um "ranking" de importância. Com ela, podemos afirmar quantitativamente que a variável **Tipo de Contrato** tem uma associação muito mais forte com o churn do que o **Método de Pagamento**, justificando a prioridade na engenharia de features.

# %%
# Loop para calcular Cramér's V para cada coluna categórica
for col in categorical_columns:
    ct = pd.crosstab(telecom_df[col], telecom_df['churn'])
    v = association(ct, method='cramer')
    print(f"{col}: Cramér's V = {v:.3f}")
# Out:
# genero: Cramér's V = 0.009
# linhas_multiplas: Cramér's V = 0.040
# tipo_internet: Cramér's V = 0.322
# seguranca_online: Cramér's V = 0.347
# backup_online: Cramér's V = 0.292
# protecao_dispositivo: Cramér's V = 0.282
# suporte_tecnico: Cramér's V = 0.343
# streaming_tv: Cramér's V = 0.231
# streaming_filmes: Cramér's V = 0.231
# tipo_contrato: Cramér's V = 0.410
# metodo_pagamento: Cramér's V = 0.303

# %% [markdown]
# **Análise de Resultados: V de Cramér**
#
# Ao cruzar os resultados do V de Cramér com os testes de hipótese anteriores, temos uma visão clara da hierarquia de importância das features:
#
# **1. Associação Forte/Moderada (Drivers de Churn):**
# Variáveis como **tipo_contrato** (V = 0.410), **seguranca_online** (V = 0.347), **suporte_tecnico** (V = 0.343) e **tipo_internet** (V = 0.322) dominam a relação com o cancelamento.
# Este resultado valida integralmente os altíssimos valores de Chi-quadrado observados. A métrica confirma que a modalidade de contratação (mensal vs. anual) e a blindagem do cliente através de serviços de suporte/segurança são os fatores mais determinantes para a retenção. O **metodo_pagamento** (V = 0.303) também entra neste grupo de elite, sugerindo que a fricção de pagamento é um fator crucial.
#
# **2. Associação Nula:**
# A variável **genero** apresenta um V de Cramér de apenas **0.009**. Isso confirma matematicamente o que o p-valor (0.4866) já havia sugerido: o gênero é ruído. Não há nenhuma força de associação, e incluir essa variável no modelo não poderá não trazer ganho preditivo algum (com cuidado nessa afirmação, já que não estamos avaliando interações entre variáveis).
#
# **3. Significância Estatística vs. Relevância Prática:**
# Aqui temos um insight valioso sobre **linhas_multiplas** (V = 0.040). Embora o teste de Chi-quadrado tenha apontado uma diferença estatisticamente significativa (p = 0.0035), o V de Cramér revela que a **força** dessa relação é desprezível. Isso significa que, embora exista uma diferença técnica entre os grupos, ela é fraca demais para ser um preditor confiável de churn por si só.
#
# **4. O "Meio de Campo" (Serviços Secundários):**
# Serviços como **backup_online**, **protecao_dispositivo** e os serviços de streaming (TV e Filmes) orbitam na faixa de V entre 0.23 e 0.29. Eles são importantes e devem ser mantidos, mas provavelmente funcionam melhor em conjunto (interações) do que isoladamente.
#
# **Resumo Estratégico para Modelagem:**
#
# * **V > 0.30 (Top Tier):** Prioridade máxima para Feature Engineering. `tipo_contrato` é a variável "alvo".
# * **V < 0.05 (Descarte):** `genero` e `linhas_multiplas` devem ser avaliados com atenção especial.
# * **Ação:** O foco do modelo deve ser capturar o comportamento de uso de serviços de internet e a estrutura contratual, mais do que características demográficas.

# %% [markdown]
# ### **Interações da variável `genero` com outras variáveis categóricas**

# %% [markdown]
# **Validação de Hipótese: O Gênero é realmente relevante?**
#
# As análises estatísticas anteriores (Qui-Quadrado e V de Cramér) indicaram que a variável **Gênero** possui associação praticamente nula com o Churn ($V = 0.009$). Em uma abordagem simplista, isso seria motivo suficiente para removê-la imediatamente.
#
# No entanto, antes de descartar a variável, precisamos verificar a existência de **interações ocultas**.
# > *Pergunta de Negócio: Será que o gênero influencia o Churn quando combinado com outras variáveis? Ex: Homens Idosos cancelam mais que Mulheres Idosas?*
#
# Nos gráficos abaixo, usamos o **Gênero** como variável de controle (separação em colunas).
#
# **Critério de Avaliação:**
# 1.  **Simetria (Descarte):** Se o gráfico da esquerda (Feminino) apresentar o mesmo padrão de distribuição e churn do gráfico da direita (Masculino) para todas as variáveis (ex: Contrato, Internet, Pagamento), isso confirma que o gênero é irrelevante em qualquer cenário.
# 2.  **Assimetria (Manutenção):** Se notarmos que para uma variável específica (ex: *TechSupport*) o comportamento muda drasticamente entre homens e mulheres, a variável deve ser mantida para capturar essa interação.

# %%
# Configuração da variável que servirá de "filtro" (Interaction Feature)
control_var = 'genero' 

# Filtramos para não plotar a variável de controle contra ela mesma
vars_to_plot = [col for col in categorical_columns if col != control_var and col != 'churn']

for var in vars_to_plot:
    # O catplot cria sua própria figura (Figure-level)
    g = sns.catplot(
        data=telecom_df, 
        x=var, 
        hue='churn', 
        col=control_var,
        kind='count', 
        height=4, 
        aspect=1.2,
        sharey=True
    )
    
    # Estilização
    g.figure.suptitle(f'Interação: {var} vs Churn (por {control_var})', 
                   fontsize=14, fontweight='bold', y=1.05)
    
    g.set_axis_labels(var, "Número de Clientes")
    
    # Ajuste fino dos eixos (rotação e limpeza)
    for ax in g.axes.flat:
        # Rotaciona labels do eixo X
        for label in ax.get_xticklabels():
            label.set_rotation(45)
            label.set_ha('right')
        
        ax.grid(axis='y', linestyle='--', alpha=0.3)

    plt.show()

# %% [markdown]
# **Conclusão Visual**
#
# Após a inspeção visual das interações (Facet Grid), observamos o **Fenômeno de Simetria**:
#
# 1.  **Padrões Idênticos:** O comportamento de churn em relação a variáveis críticas (como *tipo_contrato*, *suporte_tecnico* e *metodo_pagamento*) é visualmente idêntico para homens e mulheres.
# 2.  **Ausência de Interação:** Não há evidência de que o gênero altere a sensibilidade do cliente a preços, tipo de internet ou falta de suporte.
#
# **Decisão Final:**
# Combinando o **V de Cramér (0.009)** com a **análise visual de interações**, concluímos que a variável `genero` é possivelmente ruido para o modelo.

# %% [markdown]
# ## **Análise bivariada - numéricas vs Churn**

# %%
# Define o número de colunas e linhas para os subplots
n = len(numeric_columns)
ncols = 2
nrows = ceil(n / ncols)

# Cria a figura
fig, axes = plt.subplots(nrows, ncols, figsize=(12, nrows * 4), sharey=False)

# Achata os eixos para facilitar o loop
axes = axes.flatten()

# Plota o histograma
for ax, var in zip(axes, numeric_columns):
    sns.histplot(
        data=telecom_df,
        x=var,
        hue='churn',
        kde=True,
        stat='count',
        multiple='dodge',
        common_norm=False,
        ax=ax
    )
    
    # Título e rótulos dos eixos
    ax.set_title(f'{var}', fontsize=12, fontweight='bold')
    ax.set_xlabel(var, fontsize=12)
    ax.set_ylabel('Número de Clientes', fontsize=12)
    
    # Despine
    sns.despine(ax=ax)
    
# Título geral da figura
fig.suptitle('Distribuição de Variáveis Numéricas por Status de Churn', 
             fontsize=18, fontweight='bold', ha='center')

# Ajustes de layout e espaçamento
fig.subplots_adjust(hspace=0.4, wspace=0.3, top=0.92)

# Gira as labels do eixo x
for ax in axes:
    ax.tick_params(axis='x', labelrotation=45)
    ax.grid(axis='y', linestyle='--', linewidth=0.5, color='lightgray')

# Remove eixos não utilizados (caso número de variáveis seja ímpar)
for i in range(n, len(axes)):
    fig.delaxes(axes[i])

# Ajusta o layout para evitar sobreposição
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Salva o gráfico
#fig.savefig(plots_dir / 'churn_vs_numeric_variables.png', bbox_inches='tight', dpi=300)

# Exibe o gráfico
plt.show()

# %% [markdown]
# ### **Matriz de correlação**

# %% [markdown]
# **O que é a Correlação de Pearson ($r$)?**
#
# A **Correlação de Pearson** é a métrica estatística mais utilizada para quantificar a **associação linear** entre duas variáveis numéricas contínuas. Ela responde à pergunta: *"Quando a variável X aumenta, a variável Y tende a aumentar (positiva), diminuir (negativa) ou não mudar (neutra)?"*
#
# Para um par de vetores $X = \{x_i\}$ e $Y = \{y_i\}$ de tamanho $n$, o coeficiente $r$ é calculado normalizando a covariância entre as variáveis pelo produto dos seus desvios padrão:
#
# $$
# r = \frac{\sum_{i=1}^n (x_i - \bar x)\,(y_i - \bar y)}
#          {\sqrt{\sum_{i=1}^n (x_i - \bar x)^2 \; \sum_{i=1}^n (y_i - \bar y)^2}}
# $$
#
# **Onde:**
# - $\bar x$ e $\bar y$ são as médias aritméticas de $X$ e $Y$.
# - O numerador representa a **covariância** (como as variáveis variam juntas).
# - O denominador serve para **normalizar** o resultado, garantindo que ele fique sempre entre -1 e 1.
#
# ---
#
# **Como interpretar os valores de $r$?**
#
# O coeficiente é adimensional e oscila em uma escala fixa:
#
# * **$r = 1$ (Correlação Positiva Perfeita):** As variáveis crescem juntas em perfeita sincronia linear.
# * **$r > 0$ (Correlação Positiva):** Quando uma sobe, a outra tende a subir. Ex: *cobranca_total* tende a subir conforme *tempo_contrato_meses* aumenta.
# * **$r = 0$ (Ausência de Correlação Linear):** Não há padrão linear discernível. As variáveis são independentes ou possuem uma relação não-linear complexa.
# * **$r < 0$ (Correlação Negativa):** Quando uma sobe, a outra desce. Ex: *Churn* tende a diminuir conforme *tempo_contrato_meses* aumenta (relação inversa).
# * **$r = -1$ (Correlação Negativa Perfeita):** Relação inversa exata.
#
# **Importante para nossa Análise**
# 1.  **Linearidade:** O coeficiente de Pearson captura apenas relações **lineares**. Se a relação for curva (ex: quadrática ou exponencial), o Pearson pode indicar 0 mesmo havendo uma relação forte.
# 2.  **Sensibilidade:** É sensível a *outliers* (valores extremos), que podem distorcer o coeficiente.
# 3.  **Churn (Binário):** Quando calculamos Pearson entre uma variável contínua (ex: *cobranca_mensal*) e uma binária (ex: *Churn* 0 ou 1), o resultado é matematicamente equivalente à **Correlação Ponto-Bisserial**.

# %% [markdown]
# **Correlação de Ponto-Bisserial ($r_{pb}$)**
#
# Enquanto a correlação de Pearson é projetada para duas variáveis contínuas, a **Correlação de Ponto-Bisserial** é a métrica estatística específica para medir a relação entre uma variável **contínua** (Ex: *cobranca_mensal*) e uma variável **binária/dicotômica** (Ex: *Churn* 0 ou 1).
#
# Matematicamente, ela avalia o quanto a média da variável contínua se desloca dependendo do grupo em que ela está (Grupo 0 ou Grupo 1). O coeficiente $r_{pb}$ é dado por:
#
# $$
# r_{pb} = \frac{\bar{X}_1 - \bar{X}_0}{s_{n-1}}\,\sqrt{\frac{n_1\,n_0}{n\,(n-1)}}
# $$
#
# **Onde:**
# - $\bar{X}_1$ e $\bar{X}_0$: São as médias da variável contínua para os grupos $Y=1$ (Churn) e $Y=0$ (Não-Churn), respectivamente.
# - $s_{n-1}$: É o desvio-padrão amostral de toda a variável contínua.
# - $n_1$ e $n_0$: Quantidade de observações em cada grupo.
# - $\sqrt{\dots}$: Este termo ajusta o coeficiente baseando-se no balanceamento das classes.
#
# **Interpretação Sênior:**
# O $r_{pb}$ nos conta uma história sobre a **separabilidade** dos grupos:
# 1.  **Magnitude:** Quanto maior o valor (módulo), mais distantes estão as médias dos dois grupos. Isso sugere que a variável numérica é um bom discriminador para o modelo.
# 2.  **Sinal (+/-):**
#     * **Positivo:** A média do grupo de Churn ($Y=1$) é maior que a do grupo fiel. (Ex: Faturas mais altas).
#     * **Negativo:** A média do grupo de Churn é menor. (Ex: Tempo de casa menor).
#
# > **Nota Técnica:** Se a variável binária for codificada numericamente como 0 e 1, o cálculo do $r_{pb}$ é **matematicamente equivalente** ao $r$ de Pearson. Por isso, em códigos Python, frequentemente usamos `df.corr(method='pearson')` mesmo para esse cenário.

# %%
# Print colunas numéricas
numeric_columns
# Out:
# ['idoso',
#  'parceiro',
#  'dependentes',
#  'tempo_contrato_meses',
#  'servico_telefone',
#  'cobranca_digital',
#  'cobranca_mensal',
#  'cobranca_total',
#  'churn']

# %%
# Colunas binárias
binary_columns = [col for col in telecom_df[numeric_columns] if telecom_df[col].nunique() == 2]
binary_columns
# Out:
# ['idoso',
#  'parceiro',
#  'dependentes',
#  'servico_telefone',
#  'cobranca_digital',
#  'churn']

# %%
# Colunas numéricas contínuas excluindo binárias
continuous_numeric_columns = [col for col in numeric_columns if col not in binary_columns]
continuous_numeric_columns
# Out:
# ['tempo_contrato_meses', 'cobranca_mensal', 'cobranca_total']

# %%
# Função wrapper para pegar apenas o primeiro valor da `pointbiserialr`
def pointbiserialr_wrapper(x, y):
    """Calcula a correlação ponto-biserial entre duas variáveis.

    Args:
        x (pd.Series): A primeira variável.
        y (pd.Series): A segunda variável (binária).

    Returns:
        float: O coeficiente de correlação ponto-biserial.
    """
    return pointbiserialr(x, y)[0]

# %%
# Função para plotar matriz de correlação
def plot_correlation_matrix(df: pd.DataFrame, 
                            columns: list[str],
                            method: Union[str, Callable], 
                            plots_dir: Optional[Path] = None) -> None:
    """
    Plota a matriz de correlação para as colunas especificadas do DataFrame.
    
    :param df: DataFrame contendo os dados.
    :param columns: Lista de colunas a serem correlacionadas.
    :param method: Método de correlação a ser usado ('pearson', 'spearman', 'kendall', 'pointbiserialr').
    :param plots_dir: Diretório para salvar os gráficos.
    """
    
     # Substitui por função wrapper se for pointbiserialr
    if method == 'pointbiserialr':
        corr_func = pointbiserialr_wrapper
        method_name = 'pointbiserialr'
    else:
        corr_func = method
        method_name = method if isinstance(method, str) else method.__name__
        
    # Calcula a matriz de correlação
    corr_matrix = df[columns].corr(method=corr_func)
    
    # Cria a figura e o eixo
    fig, ax = plt.subplots(figsize=(12, 10))
    
    # Ajusta espaço superior para o suptitle
    fig.subplots_adjust(top=0.90)
    
    # Cria o heatmap
    sns.heatmap(
        corr_matrix,
        annot=True,
        fmt='.2f',
        cmap='coolwarm',
        square=True,
        cbar_kws={"shrink": .8},
        linewidths=0.5,
        linecolor='black',
    )
    
    # Título do gráfico
    ax.set_title(f'Matriz de Correlação - Método: {method_name.capitalize()}',
                fontsize=18, fontweight='bold', ha='center')
    
    # Ajustes visuais
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
    sns.despine(left=True, bottom=True)
    
    # Salva e exibe
    if plots_dir:
        save_path = plots_dir / f'correlation_matrix_{method_name}.png'
        fig.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Gráfico salvo em: {save_path}")
    else:
        print("Gráfico exibido apenas (não salvo em disco).")

    # Exibe o gráfico
    plt.show()

# %%
# Plotar a matriz de correlação para Point-Biserial
plot_correlation_matrix(telecom_df, numeric_columns, 'pointbiserialr')
# Out:
# Gráfico exibido apenas (não salvo em disco).

# %%
# Tabela de correlação para as variáveis numéricas
corr_matrix = telecom_df[numeric_columns].corr(method='pearson')

# Exibe arredondando
corr_matrix.round(3)
# Out:
#                       idoso  parceiro  dependentes  tempo_contrato_meses  \
# idoso                 1.000     0.016       -0.211                 0.017
# parceiro              0.016     1.000        0.453                 0.380
# dependentes          -0.211     0.453        1.000                 0.160
# tempo_contrato_meses  0.017     0.380        0.160                 1.000
# servico_telefone      0.009     0.018       -0.002                 0.008
# cobranca_digital      0.157    -0.015       -0.111                 0.006
# cobranca_mensal       0.220     0.097       -0.114                 0.248
# cobranca_total        0.102     0.319        0.065                 0.826
# churn                 0.151    -0.150       -0.164                -0.352
#
#                       servico_telefone  cobranca_digital  cobranca_mensal  \
# idoso                            0.009             0.157            0.220
# parceiro                         0.018            -0.015            0.097
# ...

# %%
# Plotar a matriz de correlação para Point-Biserial
plot_correlation_matrix(telecom_df, continuous_numeric_columns + ['churn'], 'pointbiserialr')
# Out:
# Gráfico exibido apenas (não salvo em disco).

# %%
# Tabela de correlação para as variáveis contínuas
corr_matrix_continuous = telecom_df[continuous_numeric_columns].corr(method='pearson')

# Exibe arredondando
corr_matrix_continuous.round(3)
# Out:
#                       tempo_contrato_meses  cobranca_mensal  cobranca_total
# tempo_contrato_meses                 1.000            0.248           0.826
# cobranca_mensal                      0.248            1.000           0.651
# cobranca_total                       0.826            0.651           1.000

# %% [markdown]
# **Análise da Matriz de Correlação (Variáveis Numéricas)**
#
# Ao analisarmos as correlações lineares (Pearson/Ponto-Bisserial) entre as variáveis numéricas e o *Churn*, bem como entre si, destacam-se três insights fundamentais para a modelagem:
#
# **1. O Principal Driver de Retenção: Tempo de Casa**
# A variável **tempo_contrato_meses** apresenta a correlação mais forte com o churn (**-0.352**). O sinal negativo confirma a intuição de negócio: quanto mais antigo o cliente, menor a probabilidade de cancelamento. Clientes novos são os mais voláteis, indicando que as estratégias de retenção devem ser agressivas nos primeiros meses de vida.
#
# **2. Alerta de Multicolinearidade (Perigo!)**
# Observamos uma correlação altíssima de **0.826** entre **tempo_contrato_meses** e **cobranca_total**. Isso é esperado (Total = Mensal × Tempo), mas tecnicamente problemático.
# > **Decisão de Modelagem:** Manter ambas as variáveis em modelos lineares (como Regressão Logística) causará instabilidade nos coeficientes. Recomenda-se remover **cobranca_total** ou utilizar modelos de árvore (Random Forest/XGBoost) que lidam bem com essa redundância.
#
# **3. Impacto do Preço e Pagamento**
# A **cobranca_mensal** possui uma correlação positiva relevante (**0.193**), indicando que clientes com planos mais caros tendem a cancelar mais. Curiosamente, a **cobranca_digital** (Paperless Billing) tem um impacto quase idêntico (**0.192**), sugerindo que a facilidade (ou a fricção) digital pode estar associada a um perfil de cliente mais propenso à troca de operadora.
#
# **4. Variáveis sem Correlação Linear**
# A variável **servico_telefone** apresenta correlação próxima de zero (**0.012**), reforçando o que vimos nos testes de Qui-Quadrado: ter ou não telefone não dita o churn. Já **dependentes** tem uma correlação negativa moderada (**-0.164**), sugerindo que famílias tendem a ser ligeiramente mais fiéis.
#
# **Conclusão:**
# O foco deve estar no *ciclo de vida* (`tempo_contrato_meses`) e na *sensibilidade ao preço* (`cobranca_mensal`). A variável `cobranca_total` deve ser tratada com cautela devido à multicolinearidade.

# %% [markdown]
# ### **Multicolinearidade entre variáveis numéricas por meio do VIF**

# %% [markdown]
# **Fator de Inflação da Variância (VIF)**
#
# O **Fator de Inflação da Variância** (*Variance Inflation Factor*, VIF) é a métrica padrão para detectar a severidade da **multicolinearidade** em uma análise de regressão. A multicolinearidade ocorre quando uma variável independente (preditora) pode ser linearmente prevista com alta precisão por outras variáveis independentes do modelo.
#
# Embora a correlação de Pearson mostre a relação entre *pares* de variáveis, o VIF captura se uma variável é redundante considerando *todas* as outras variáveis simultaneamente (multicolinearidade múltipla).
#
# **1. O Conceito Matemático**
# Para calcular o VIF de uma variável específica $X_j$, construímos uma **regressão linear auxiliar** onde $X_j$ é usada como variável resposta (alvo) e todas as outras variáveis preditoras ($X_{k, k \neq j}$) são usadas para tentar predizê-la.
#
# Dessa regressão auxiliar, extraímos o **Coeficiente de Determinação** ($R^2_j$). O VIF é então calculado como:
#
# $$
# VIF_j = \frac{1}{1 - R_j^2}
# $$
#
# **Onde:**
# - $R_j^2$: Representa a proporção da variância de $X_j$ que é explicada pelas outras variáveis independentes.
#
# **2. Interpretação da Fórmula**
# A intuição matemática é direta:
# - **Se $R_j^2 = 0$:** As outras variáveis não conseguem explicar nada de $X_j$. O denominador vira 1 e o $VIF = 1$ (Ausência de multicolinearidade).
# - **Se $R_j^2 \to 1$:** As outras variáveis explicam $X_j$ quase perfeitamente. O denominador tende a 0 e o $VIF \to \infty$ (Multicolinearidade perfeita).
#
# **3. Regras de Bolso (Thresholds)**
# Na prática de Ciência de Dados, utilizamos os seguintes limites para diagnóstico:
#
# * **VIF = 1:** Variável totalmente independente (Ideal).
# * **1 < VIF < 5:** Correlação moderada. Geralmente aceitável para a maioria dos modelos.
# * **VIF $\ge$ 5:** Alta multicolinearidade. A variável é altamente redundante. Recomenda-se investigação.
# * **VIF > 10:** Multicolinearidade crítica. Os coeficientes do modelo tornam-se instáveis e os p-valores não confiáveis. A remoção da variável é fortemente recomendada.
#
# > **Nota de Modelagem:** A multicolinearidade (VIF alto) é um problema grave para modelos lineares (Regressão Logística, Linear, SVM Linear) pois infla o erro padrão dos coeficientes, tornando o modelo instável. Para modelos baseados em árvores (Random Forest, XGBoost), o VIF alto é menos crítico, pois esses algoritmos lidam nativamente com redundância através do *feature bagging* e cortes hierárquicos.

# %%
# Função para calcular o VIF
def calculate_vif(df, features):
    """
    Calcula o VIF (Variance Inflation Factor) para uma lista de features numéricas.
    """
    # 1. Seleciona apenas as colunas numéricas e remove nulos (VIF não aceita NaNs)
    X = df[features].copy().dropna()
    
    # 2. Adiciona a constante (Intercepto)
    # Essencial para o cálculo correto do R^2 na regressão auxiliar
    X = add_constant(X)
    
    # 3. Loop para calcular VIF de cada variável
    vif_data = []
    for i in range(len(X.columns)):
        col_name = X.columns[i]
        
        # Ignora a constante no output final, queremos ver apenas as features
        if col_name != 'const':
            vif_value = variance_inflation_factor(X.values, i)
            vif_data.append([col_name, vif_value])
    
    # 4. Cria DataFrame e ordena
    vif_df = pd.DataFrame(vif_data, columns=["Variável", "VIF"])
    return vif_df.sort_values(by="VIF", ascending=False)

# %%
# Calcula o VIF para as variáveis numéricas (excluindo 'churn')
df_vif = calculate_vif(telecom_df, [col for col in numeric_columns if col not in ('churn')])

# Exibe
print("--- Análise de Multicolinearidade (VIF) ---\n")
df_vif
# Out:
# --- Análise de Multicolinearidade (VIF) ---
#                Variável       VIF
# 7        cobranca_total  9.575154
# 3  tempo_contrato_meses  6.006284
# 6       cobranca_mensal  3.666371
# 1              parceiro  1.458246
# 2           dependentes  1.363651
# 5      cobranca_digital  1.170472
# 0                 idoso  1.112463
# 4      servico_telefone  1.081189

# %% [markdown]
# **Diagnóstico de Multicolinearidade (VIF)**
#
# A análise do Fator de Inflação da Variância (VIF) confirma a suspeita levantada na matriz de correlação: existe uma redundância estrutural entre as variáveis financeiras e de tempo.
#
# **1. Zona de Risco (VIF > 5):**
# - **cobranca_total (VIF = 9.58):** Apresenta valor extremamente próximo do limiar crítico de 10. Isso ocorre porque ela é matematicamente derivada das outras duas variáveis (`cobranca_mensal` $\times$ `tempo_contrato`). Manter essa variável em modelos lineares (como Regressão Logística) irá inflar o erro padrão dos coeficientes, tornando o modelo instável.
# - **tempo_contrato_meses (VIF = 6.01):** Também apresenta multicolinearidade elevada, cruzando a barreira de VIF > 5, justamente pela sua forte correlação com o total pago.
#
# **2. Zona Segura (VIF < 5):**
# - **cobranca_mensal (VIF = 3.67):** Embora tenha alguma correlação com as demais, seu VIF está em um patamar aceitável, indicando que ela traz informação única suficiente para ser mantida.
# - **Variáveis Binárias/Demográficas:** Variáveis como `parceiro`, `dependentes` e `idoso` apresentam VIF muito próximo de 1, indicando independência linear quase total. Elas são seguras para qualquer tipo de modelagem.
#
# **Decisão Estratégica para Modelagem:**
# > Para evitar a instabilidade numérica em algoritmos sensíveis à multicolinearidade (Regressão Logística, SVM Linear), recomenda-se **remover a variável `cobranca_total`**.
#
# Essa remoção resolve o problema da redundância sem perda significativa de informação, pois o efeito do valor total já será capturado pela interação entre o tempo de casa e a cobrança mensal.

# %%
# Calcula o VIF sem a variável 'cobranca_total'
numeric_cols_without_total = [col for col in numeric_columns if col not in ('churn', 'cobranca_total')]
df_vif_no_total = calculate_vif(telecom_df, numeric_cols_without_total)

# Exibe
print("--- Análise de Multicolinearidade (VIF) sem 'cobranca_total' ---\n")
df_vif_no_total
# Out:
# --- Análise de Multicolinearidade (VIF) sem 'cobranca_total' ---
#                Variável       VIF
# 1              parceiro  1.457763
# 6       cobranca_mensal  1.383680
# 2           dependentes  1.364962
# 3  tempo_contrato_meses  1.247684
# 5      cobranca_digital  1.168429
# 0                 idoso  1.110862
# 4      servico_telefone  1.078963

# %% [markdown]
# ## **Informação mútua (Mutual Information)**

# %% [markdown]
# **Informação Mútua (Mutual Information)**
#
# A **Informação Mútua (MI)** é uma métrica fundamental da Teoria da Informação que quantifica a dependência entre duas variáveis aleatórias. Diferente da correlação, que mede apenas relações lineares, a MI mede a **redução da incerteza**: ela nos diz o quanto saber o valor de uma variável $Y$ reduz a nossa "surpresa" sobre a variável $X$.
#
# **1. O Conceito de Entropia e Incerteza**
# Para entender MI, primeiro definimos a **Entropia de Shannon** ($H$), que mede a incerteza média de uma variável aleatória $X$:
#
# $$
# H(X) = -\sum_x p(x)\,\log p(x)
# $$
#
# Se duas variáveis $X$ e $Y$ fossem totalmente independentes, sua distribuição conjunta seria apenas o produto de suas marginais: $p(x,y) = p(x)p(y)$. Qualquer desvio dessa igualdade sinaliza que existe uma conexão (informação) entre elas.
#
# **2. Definição Formal (Divergência KL)**
# A Informação Mútua é definida formalmente como a **Divergência de Kullback–Leibler (KL)** entre a distribuição conjunta real e a distribuição teórica caso fossem independentes:
#
# $$
# I(X;Y) = \sum_{x,y} p(x,y)\,\log \frac{p(x,y)}{p(x)\,p(y)}
# $$
#
# * **Se $X$ e $Y$ são independentes:** O termo dentro do log vira 1, o log vira 0, e $I(X;Y) = 0$.
# * **Se existe dependência:** O valor será positivo. Quanto maior o valor, mais forte é a relação.
#
# **3. Interpretação Intuitiva (Redução de Incerteza)**
# Uma forma mais prática de visualizar a MI é através da subtração de entropias:
#
# $$
# I(X;Y) = H(X) - H(X|Y)
# $$
#
# Isso significa: **"A Informação Mútua é a Entropia inicial de X menos a Entropia que resta em X depois que descobrimos Y."**
# Graficamente, em um diagrama de Venn, a MI corresponde à área de **interseção** entre as incertezas das duas variáveis.
#
# **4. Propriedades e Unidades**
# As principais propriedades da MI são:
# 1.  **Não-negatividade:** $I(X;Y) \ge 0$.
# 2.  **Simetria:** $I(X;Y) = I(Y;X)$.
# 3.  **Dependência da Base:** A unidade de medida da informação é definida pela base do logaritmo utilizado na fórmula:
#     * **Bits (Shannon):** Quando usamos $\log_2$. É a unidade padrão em Ciência da Computação.
#     * **Nats:** Quando usamos $\log_e$ (logaritmo natural). É o padrão em bibliotecas matemáticas e frameworks como *scikit-learn*.
#     * **Hartleys (Ban/Dit):** Quando usamos $\log_{10}$.
#
# > **Diferença Crucial para o Pearson:**
# > Enquanto a Correlação de Pearson falha em detectar relações não-lineares (ex: uma relação quadrática perfeita pode ter Pearson $\approx 0$), a Informação Mútua é **model-agnostic**. Ela detectará dependência estatística forte seja a relação uma reta, uma parábola ou uma onda senoidal.

# %%
# Função auxiliar para calcular a informação mútua
def make_mi_scores_classification(
    X: pd.DataFrame,
    y: pd.Series,
    discrete_features: Union[bool, list[str], str] = True,
) -> pd.Series:
    mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
    mi_scores_series = pd.Series(mi_scores, name= 'MI Scores', index=X.columns)
    return mi_scores_series

# %%
# Separação das features (X) e do target (y)

# Removemos valores ausentes com .dropna()
# Excluímos a coluna 'id_cliente', pois é apenas identificadora
# Usamos .copy() para evitar alterações no DataFrame original
# Usamos .pop('churn') para extrair a variável-alvo e removê-la de X
# (o método pop é inplace e retorna a série ao mesmo tempo)

X = (
    telecom_df
        .dropna()
        .copy()
)

y = X.pop('churn')

# %%
# Aplica o pd.factorize para as colunas categóricas
for col in categorical_columns:
    X[col], _ = pd.factorize(X[col])

# Verifica se as colunas categóricas foram convertidas corretamente
X[categorical_columns].sample(5)
# Out:
#       genero  linhas_multiplas  tipo_internet  seguranca_online  \
# 1545       1                 2              1                 0
# 5205       0                 2              1                 1
# 4515       0                 1              1                 0
# 2730       1                 2              1                 0
# 1365       1                 0              0                 0
#
#       backup_online  protecao_dispositivo  suporte_tecnico  streaming_tv  \
# 1545              0                     1                0             1
# 5205              0                     1                0             0
# 4515              0                     0                0             1
# 2730              0                     0                1             1
# 1365              0                     0                0             0
#
#       streaming_filmes  tipo_contrato  metodo_pagamento
# 1545                 1              2                 2
# ...

# %%
# Cria uma máscara booleana para informar quais variáveis são discretas
discrete_features = X.dtypes == int

discrete_features
# Out:
# genero                   True
# idoso                   False
# parceiro                False
# dependentes             False
# tempo_contrato_meses    False
# servico_telefone        False
# linhas_multiplas         True
# tipo_internet            True
# seguranca_online         True
# backup_online            True
# protecao_dispositivo     True
# suporte_tecnico          True
# streaming_tv             True
# streaming_filmes         True
# tipo_contrato            True
# cobranca_digital        False
# metodo_pagamento         True
# cobranca_mensal         False
# cobranca_total          False
# dtype: bool

# %%
# Usa a função para calcular a informação mútua
mi_scores = make_mi_scores_classification(X, y, discrete_features)

# Exibe os scores de informação mútua
mi_scores.sort_values(ascending=False)
# Out:
# tipo_contrato           0.098182
# tempo_contrato_meses    0.074529
# seguranca_online        0.064528
# suporte_tecnico         0.062873
# tipo_internet           0.055394
# backup_online           0.046659
# cobranca_mensal         0.045582
# metodo_pagamento        0.044423
# protecao_dispositivo    0.043784
# cobranca_total          0.042851
# streaming_filmes        0.031918
# streaming_tv            0.031803
# dependentes             0.021279
# idoso                   0.012574
# cobranca_digital        0.010330
# parceiro                0.010172
# servico_telefone        0.006802
# linhas_multiplas        0.000798
# genero                  0.000037
# Name: MI Scores, dtype: float64

# %% [markdown]
# **Análise de Informação Mútua (Mutual Information)**
#
# Ao analisarmos os scores de Informação Mútua (MI), obtemos uma validação robusta das relações detectadas anteriormente, mas com a vantagem de capturar dependências não-lineares que a correlação de Pearson poderia perder.
#
# **1. O Pilar da Fidelização: Contrato e Tempo**
# O **tipo_contrato** lidera o ranking de importância com um score de **0.098**, confirmando ser o maior determinante do churn. Logo em seguida, temos a variável numérica **tempo_contrato_meses** (Tenure) com **0.082**.
# > *Insight:* A alta pontuação de `tempo_contrato_meses` aqui corrobora a forte correlação negativa vista na matriz de Pearson (-0.35). Ambas as métricas gritam a mesma mensagem: o ciclo de vida do cliente é o fator crítico de retenção.
#
# **2. O Ecossistema de Proteção (Barreiras de Saída)**
# Observamos um cluster de alta relevância formado por serviços de valor agregado: **seguranca_online** (0.065), **suporte_tecnico** (0.063) e **tipo_internet** (0.055).
# Isso reforça os achados do V de Cramér: clientes que contratam serviços de proteção ou suporte técnico criam uma "blindagem" contra o cancelamento, tornando esses serviços estratégicos para ações de marketing e upsell.
#
# **3. Aspectos Financeiros**
# Variáveis como **metodo_pagamento** (0.044), **cobranca_mensal** (0.044) e **cobranca_total** (0.043) aparecem em um patamar intermediário. Embora não sejam os preditores primários, carregam informação significativa sobre a sensibilidade ao preço e atrito de pagamento.
#
# **4. Confirmação de Ruído (Candidatos a Exclusão)**
# A análise de MI coloca o último prego no caixão de certas variáveis. **genero** (0.000037), **linhas_multiplas** (0.0008) e **servico_telefone** (0.0027) apresentam valores virtualmente nulos.
# > *Conclusão Definitiva:* Diferente do teste de Qui-Quadrado, que apontou significância estatística (p < 0.05) para `linhas_multiplas`, a Informação Mútua revela que o ganho real de informação dessa variável é desprezível. Isso nos dá segurança total para remover essas três variáveis da modelagem preditiva, simplificando o modelo sem perda de performance.

# %% [markdown]
# ## **Outliers e inconsistências**

# %%
# Função para plotar boxplot
def plot_outliers_boxplot(df: pd.DataFrame, 
                          numeric_columns: list[str],
                          target_column: Optional[str] = None,
                          plots_dir: Optional[Path] = None) -> None:
    """
    Plota boxplots para análise de outliers em variáveis numéricas, opcionalmente
    separados por uma variável alvo (target).
    
    :param df: DataFrame contendo os dados.
    :param numeric_columns: Lista de colunas numéricas para analisar.
    :param target_column: Nome da variável alvo (ex: 'Churn') para segmentar o eixo X.
    :param plots_dir: Diretório opcional para salvar a figura.
    """
    
    # Configuração dinâmica do grid (1 linha, N colunas)
    n_cols = len(numeric_columns)
    
    # Cria a figura e os eixos (desempacota axes se for apenas 1 coluna)
    fig, axes = plt.subplots(nrows=1, ncols=n_cols, figsize=(5 * n_cols, 6))
    
    # Garante que axes seja sempre iterável (lista), mesmo se for apenas 1 plot
    if n_cols == 1:
        axes = [axes]
        
    # Título Geral da Figura
    fig.suptitle('Análise de Outliers (Boxplot)', fontsize=20, fontweight='bold', y=1.05)
    
    # Loop pelos eixos e colunas simultaneamente
    for ax, col in zip(axes, numeric_columns):
        
        # Plotagem usando Seaborn no eixo específico (ax)
        sns.boxplot(
            data=df,
            y=col,
            x=target_column,
            hue=target_column,
            legend=False,
            ax=ax,
            palette='Set2' if target_column else 'vlag',
            linewidth=1.5,
            flierprops={"marker": "o", "markerfacecolor": "red", "markersize": 5, "alpha": 0.6}
        )
        
        # Título de cada subplot
        ax.set_title(f'Distribuição: {col}', fontsize=14, fontweight='bold', pad=15)
        
        # Ajustes visuais
        ax.grid(axis='y', linestyle='--', alpha=0.4)
        ax.set_xlabel(target_column if target_column else '', fontsize=12)
        ax.set_ylabel('Valor', fontsize=12)
        
        # Remove bordas desnecessárias
        sns.despine(ax=ax, trim=True)

    # Ajusta o layout
    plt.tight_layout()
    
    # Salva e exibe
    if plots_dir:
        suffix = f"_by_{target_column}" if target_column else ""
        save_path = plots_dir / f'outliers_boxplot{suffix}.png'
        fig.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Gráfico salvo em: {save_path}")
    else:
        print("Gráfico exibido apenas (não salvo em disco).")

    plt.show()

# %%
# Visão Analítica (Quebrando por Churn)
plot_outliers_boxplot(telecom_df, 
                      numeric_columns=continuous_numeric_columns, 
                      target_column='churn')
# Out:
# Gráfico exibido apenas (não salvo em disco).

# %% [markdown]
# **Análise Detalhada das Distribuições (Boxplot)**
#
# Ao segmentar as variáveis contínuas pelo status de *Churn*, observamos padrões distintos de distribuição e variabilidade:
#
# **1. Tempo de Contrato (`tempo_contrato_meses`)**
# * **Clientes Retidos (Churn=0):** Apresentam alta **dispersão** e uma distribuição simétrica (mediana centralizada no IQR), indicando uma base diversificada que inclui desde novos clientes até perfis de longa fidelidade.
# * **Clientes em Churn (Churn=1):** A distribuição apresenta forte **assimetria positiva** (mediana deslocada para a base inferior e caixa compacta). Isso confirma que o cancelamento é um fenômeno predominantemente precoce ("early churn").
# * **Outliers:** A presença de *outliers* superiores no grupo de Churn revela um subgrupo crítico: clientes de longa data que cancelaram repentinamente, exigindo investigação qualitativa separada.
#
# **2. Cobrança Mensal (`cobranca_mensal`)**
# * **Padrão de Dispersão:** Para o grupo retido (Churn=0), a amplitude interquartil (IQR) é maior, sugerindo que a fidelização ocorre em diversas faixas de preço.
# * **Deslocamento de Distribuição:** No grupo de Churn (Churn=1), a mediana é significativamente mais elevada e a distribuição concentra-se no quartil superior. A ausência de cauda inferior relevante sugere uma **sensibilidade ao preço**: clientes com tickets mais altos têm maior probabilidade de evasão.
# * **Outliers:** A ausência de *outliers* em ambas as classes indica que os valores praticados estão dentro dos limites padronizados dos planos de serviço.
#
# **3. Cobrança Total (`cobranca_total`)**
# * **Correlação com Tempo:** A morfologia desta variável espelha a do `tempo_contrato`. Para Churn=1, a caixa é extremamente comprimida próxima a zero, refletindo o curto ciclo de vida desses clientes.
# * **High-Value Churners:** Embora a mediana seja baixa, os *outliers* superiores no grupo de Churn (Churn=1) são de extrema importância estratégica. Eles representam clientes que geraram alto LTV (*Lifetime Value*) acumulado antes de sair, contradizendo a tendência geral do grupo.

# %% [markdown]
# ## **Salvando os dados processados**

# %%
# Salva em parquet com engine pyarrow para manter os tipos de dados
nome_arquivo = "telecom_churn_processed.parquet"
caminho_arquivo = PROCESSED_DATA_DIR / nome_arquivo
telecom_df.to_parquet(caminho_arquivo, engine='pyarrow', index=False)

# %% [markdown]
# ## **Resumo de insights**

# %% [markdown]
# **Perfil da Base de Clientes**
# A base de dados conta com **7.043 clientes** ativos e inativos, com uma taxa de cancelamento (Churn) de **26,5%**, indicando um desbalanceamento moderado que exigirá estratégias específicas na modelagem (como *class_weight* ou *resampling*).
#
# * **Demografia:** A base é equilibrada em gênero, mas predominantemente jovem (apenas **16,2% idosos**) e sem dependentes (~70%), sugerindo um perfil com menor "fricção" familiar para troca de serviços.
# * **Preferências de Serviço:** Há uma preferência clara por velocidade (**Fibra Óptica** é o tipo de internet mais comum) e conveniência (**Cheque Eletrônico** é o principal meio de pagamento).
# * **Adoção de Serviços Extras:** Existe uma lacuna de proteção. A maioria dos clientes **não contrata** serviços de segurança, backup ou suporte técnico, o que, como veremos, é um fator de risco.
#
# ---
#
# **Os Arquitetos do Churn (Principais Drivers)**
# A triangulação entre *Qui-Quadrado*, *V de Cramér* e *Informação Mútua (MI)* revelou hierarquia clara de fatores que influenciam o cancelamento:
#
# **A. O Fator Contratual (Top Tier)**
# O **Tipo de Contrato** é, indiscutivelmente, o maior preditor de churn ($V = 0.410$, MI $\approx$ 0.10).
# * Clientes com contratos **mensais** possuem altíssima volatilidade.
# * A fidelização (contratos de 1 ou 2 anos) reduz drasticamente o risco de saída.
#
# **B. O Efeito "Blindagem" (Serviços de Proteção)**
# Identificamos um cluster de retenção formado por **Segurança Online**, **Suporte Técnico** e **Backup Online**.
# * A ausência desses serviços aumenta a vulnerabilidade do cliente.
# * Clientes que contratam o "ecossistema" de proteção tendem a criar raízes e permanecer na base (efeito *Lock-in*).
#
# **C. O Ciclo de Vida (Tenure)**
# A correlação negativa forte (**-0.352**) entre `tempo_contrato_meses` e Churn confirma o fenômeno do **"Early Churn"**. O risco de cancelamento é concentrado nos primeiros meses de vida do cliente. Superada a fase inicial, a probabilidade de retenção aumenta exponencialmente.
#
# ---
#
# **3. Dinâmica Financeira**
# A análise das variáveis financeiras revelou que o preço é um fator sensível:
#
# * **Sensibilidade ao Preço:** A correlação positiva (**0.193**) da `cobranca_mensal` com o Churn indica que clientes com tickets mais altos (provavelmente planos Fibra + Streaming) são mais propensos a cancelar se não perceberem valor imediato.
# * **High-Value Churners:** A análise de *outliers* na `cobranca_total` detectou um grupo crítico de clientes que, apesar de terem gerado alta receita acumulada (LTV), cancelaram o serviço.
#     > **Decisão:** Estes outliers **NÃO** serão removidos, pois representam a perda financeira mais dolorosa para a empresa e o modelo precisa aprender a identificar esse padrão.
#
# ---
#
# **4. Estratégia de Engenharia de Dados (Feature Selection)**
# Com base nos testes estatísticos (VIF, Correlação e MI):
#
# **O que Manter e Transformar**
# * **Foco no Ciclo de Vida:** Criar *features* que capturem a maturação do cliente (ex: *bins* de tenure).
# * **Serviços Agregados:** Considerar a criação de uma variável sintética (ex: `qtd_servicos_protecao`) para capturar o grau de vínculo com o ecossistema da empresa.
#
# **O que Tratar (Multicolinearidade)**
# * A variável **`cobranca_total`** apresentou VIF crítico (**9.58**) e correlação de **0.82** com o tempo de contrato.
#     > **Ação:** Para modelos lineares (Regressão Logística), esta variável é uma candidata à **remoção** para evitar instabilidade. Para modelos de árvore (Random Forest, XGBoost), ela pode ser mantida, mas com cautela.
#
# **O que Descartar (Ruído)**
# * A variável **`genero`** apresentou associação nula em todas as métricas ($V \approx 0.009$, MI $\approx$ 0.00003). A análise visual de interações confirmou que não há comportamento diferenciado entre homens e mulheres.
# * As variáveis **`linhas_multiplas`** e **`servico_telefone`** também apresentaram poder preditivo marginal.
#     > **Ação:** Estas variáveis são candidatas fortes à exclusão para simplificar o modelo sem perda de performance.
#
# ---
#
# **Conclusão Final**
# O Churn nesta empresa não é um evento aleatório demográfico. Ele é estrutural e financeiro. O cliente que cancela é tipicamente aquele com **contrato mensal**, **recém-chegado**, que paga um **ticket alto** e **não possui serviços de suporte/segurança** atrelados à conta. O modelo preditivo deve focar rigorosamente nessas dimensões.
